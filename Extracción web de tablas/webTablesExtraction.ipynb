# %%
# !pip install pandas
# !pip install lxml
# Out:
# ...
#    ---------------------------------------- 0.0/3.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/3.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/3.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/3.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/3.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/3.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/3.8 MB 2.0 MB/s eta 0:00:02
#    ---------------------------------------- 0.0/3.8 MB 2.0 MB/s eta 0:00:02
#    ---------------------------------------- 0.0/3.8 MB 2.0 MB/s eta 0:00:02
#    ---------------------------------------- 0.0/3.8 MB 2.0 MB/s eta 0:00:02
#    ---------------------------------------- 0.0/3.8 MB 2.0 MB/s eta 0:00:02
#    ---------------------------------------- 0.0/3.8 MB 2.0 MB/s eta 0:00:02
#    ---------------------------------------- 0.0/3.8 MB 2.0 MB/s eta 0:00:02
# ...

# %%
import pandas as pd

# %%
pathTable = pd.read_html("https://es.wikipedia.org/wiki/Lionel_Messi")
pathTable
# Out:
# [                                         Lionel Messi  \
#  0                                 Medallista olímpico
#  1                            Messi en el Mundial 2022
#  2                                    Datos personales
#  3                                     Nombre completo
#  4                                Nombre de nacimiento
#  5                                            Apodo(s)
#  6                                          Nacimiento
#  7                                    Nacionalidad(es)
#  8                                              Altura
#  9                                                Peso
#  10                                             Pareja
#  11                                  Carrera deportiva
#  12                                            Deporte
#  13                                   Club profesional
#  14                                    Debut deportivo
#  15                                               Club
# ...

# %%
len(pathTable)
# Out:
# 17

# %%
pathTable[9]
# Out:
#                                   Torneo            Sede         Resultado  \
# 0                      Copa Mundial 2006        Alemania  Cuartos de final
# 1                      Copa América 2007       Venezuela        Subcampeón
# 2                      Copa Mundial 2010       Sudáfrica  Cuartos de final
# 3                      Copa América 2011       Argentina  Cuartos de final
# 4                      Copa Mundial 2014          Brasil        Subcampeón
# 5                      Copa América 2015           Chile        Subcampeón
# 6                      Copa América 2016  Estados Unidos        Subcampeón
# 7                      Copa Mundial 2018           Rusia  Octavos de final
# 8                      Copa América 2019          Brasil     Tercer puesto
# 9                      Copa América 2021          Brasil           Campeón
# 10  Copa de Campeones Conmebol-UEFA 2022         Londres           Campeón
# ...
